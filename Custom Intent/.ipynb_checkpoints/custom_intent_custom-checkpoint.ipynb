# %%
import numpy as np
import pandas as pd
import json
import os

# %%
df = pd.read_csv (r'C:\Users\DhanrajChowdhury\OneDrive - SPIKEWELL\IntentClassifier\Custom Intent\custom\data.csv')
# df_test = pd.read_csv (r'C:\Users\DhanrajChowdhury\OneDrive - SPIKEWELL\IntentClassifier\Custom Intent\atis_snips\snips\test.csv')

# df_train = df_train[df_train["intent"].str.contains("#")==False]
# df_test = df_test[df_test["intent"].str.contains("#")==False]

# df = df_train.append(df_test, ignore_index=True)
# df = pd.concat([df_train, df_test], ignore_index=True, sort=False)

text = df['text']
labels = df['intent']

classes = np.unique(labels)

# %%
#convert_to_dataframe

data = pd.DataFrame({'text': text, 'intent': labels})
print(data)
# Out:
#                                                  text          intent
# 0   Unable to Print from Scheduler. No Printers Ap...   Printer Issue
# 1             mouse is not showing in the device list  Hardware Issue
# 2             Reset STAR Password Allscripts McKesson     Login Issue
# 3                How to Filter Medications and Orders    Search Issue
# 4                            Web Browser Installation  Software Issue
# 5       How to Create a New PowerNote from an old one  Software Issue
# 6                   The paper is stuck in the printer   Printer Issue
# 7                         Client is already logged in     Login Issue
# 8   Resetting Bridge Medical (Blood Transfusion) P...     Login Issue
# 9                                        Login Issues     Login Issue
# 10                      Find ARCHIVED IRM Code Pagers    Search Issue
# 11                        Printer not showing in list   Printer Issue
# 12                        How to find the OR Schedule    Search Issue
# 13  Failed Network Connectivity Error Message:  RP...  Software Issue
# 14          How to Submit a Technology Review Request    Search Issue
# 15  One or more employees are not showing up on ma...    Search Issue
# 16                                      User Security     Login Issue
# 17                    How to get an Anesthesia Record    Search Issue
# 18                          The remote is not working  Hardware Issue
# 19           e-Prescribe Dispense Units not available    Search Issue
# 20                        How to Reset Citrix Profile     Login Issue
# 21           How to find my application on the server    Search Issue
# 22                                     Password reset     Login Issue
# 23  Powernote Error: Error in the text filter: Ill...  Software Issue
# 24                         Windows Activation pop out  Software Issue
# 25                How to change Clairvia web password     Login Issue
# 26  Can't log in to OCIE. Forgot password or accou...     Login Issue
# 27                         Application Not opening up  Software Issue
# 28   Cisco Security Appliance Wired Connection Issues  Hardware Issue
# 29  How to enable a computer that is not connectin...  Hardware Issue
# 30                     Access Requests on Cisco Webex     Login Issue
# 31                       Overview and Troubleshooting  Software Issue
# 32            User Cannot Login to iLearn (SSO Error)     Login Issue
# 33  Unable to connect through remote desktop conne...  Software Issue
# 34  Outlook Preventing email forwarding on MAC dev...  Software Issue
# 35                Secure Printing to Kyocera Printers   Printer Issue
# 36          Outlook - Program only opens in safe mode  Software Issue
# 37  SharePoint Online - User is prompted to login ...     Login Issue
# 38  Adding the charges to the ambulatory summary page  Software Issue
# 39  Chrome - Can't open, asking for administrator ...     Login Issue
# 40           Calendars Not Syncing on iPhone and iPad  Software Issue
# 41  iPhone or iPad - kids powerchart Aria EEG iPho...  Hardware Issue
# 42  How to Set Internet Explorer as the Default Br...  Software Issue
# 43  Outlook Web App - How to set up Out of office ...  Software Issue
# 44                         Access to CAFE application     Login Issue
# 45  Encounter Search box is blank; can't search fo...    Search Issue
# 46                The printing preview is not showing   Printer Issue
# 47                      Monitor and Mouse not working  Hardware Issue
# 48  PeopleSoft - Error, "Only one primary email ad...     Login Issue
# 49      Employee Barcodes not scanning on the machine  Hardware Issue

# %%
with pd.option_context('display.max_rows', None):
    print(data.groupby("intent").count())
    
data.groupby("intent").count().shape
# Out:
#                 text
# intent
# Hardware Issue     7
# Login Issue       15
# Printer Issue      5
# Search Issue       9
# Software Issue    14
# (5, 1)

# %%
classes
# Out:
# array(['Hardware Issue', 'Login Issue', 'Printer Issue', 'Search Issue',
#        'Software Issue'], dtype=object)

# %%
#convert_to_lower_case

data["lower"] = data.text.map(lambda x : x.lower())

# %%
# import nltk
# nltk.download("punkt")
# nltk.download("stopwords")
# nltk.download("wordnet")
# nltk.download('omw-1.4')

# %%
#word_tokenize

from nltk import word_tokenize

data["tokenized"] = data.lower.map(word_tokenize)

# %%
#stopwords_remove

from nltk.corpus import stopwords
from string import punctuation

def remove_stop(strings, stop_list):
    classed = [s for s in strings if s not in stop_list]
    return classed

stop = stopwords.words("english")
stop_punc = list(set(punctuation)) + stop

data["selected"] = data.tokenized.map(lambda df: remove_stop(df, stop_punc))

# %%
#normalize

from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer
from nltk.stem import WordNetLemmatizer
  
lemmatizer = WordNetLemmatizer()

def normalize(text):
    return " ".join(text)

stemmer = LancasterStemmer()

data["lemmatized"] = data.selected.map(lambda xs: [lemmatizer.lemmatize(x) for x in xs])
data["normalized"] = data.lemmatized.apply(normalize)

data
# Out:
#                                                  text          intent  \
# 0   Unable to Print from Scheduler. No Printers Ap...   Printer Issue
# 1             mouse is not showing in the device list  Hardware Issue
# 2             Reset STAR Password Allscripts McKesson     Login Issue
# 3                How to Filter Medications and Orders    Search Issue
# 4                            Web Browser Installation  Software Issue
# 5       How to Create a New PowerNote from an old one  Software Issue
# 6                   The paper is stuck in the printer   Printer Issue
# 7                         Client is already logged in     Login Issue
# 8   Resetting Bridge Medical (Blood Transfusion) P...     Login Issue
# 9                                        Login Issues     Login Issue
# 10                      Find ARCHIVED IRM Code Pagers    Search Issue
# 11                        Printer not showing in list   Printer Issue
# 12                        How to find the OR Schedule    Search Issue
# 13  Failed Network Connectivity Error Message:  RP...  Software Issue
# 14          How to Submit a Technology Review Request    Search Issue
# 15  One or more employees are not showing up on ma...    Search Issue
# 16                                      User Security     Login Issue
# 17                    How to get an Anesthesia Record    Search Issue
# 18                          The remote is not working  Hardware Issue
# 19           e-Prescribe Dispense Units not available    Search Issue
# 20                        How to Reset Citrix Profile     Login Issue
# 21           How to find my application on the server    Search Issue
# 22                                     Password reset     Login Issue
# 23  Powernote Error: Error in the text filter: Ill...  Software Issue
# 24                         Windows Activation pop out  Software Issue
# 25                How to change Clairvia web password     Login Issue
# 26  Can't log in to OCIE. Forgot password or accou...     Login Issue
# 27                         Application Not opening up  Software Issue
# 28   Cisco Security Appliance Wired Connection Issues  Hardware Issue
# 29  How to enable a computer that is not connectin...  Hardware Issue
# 30                     Access Requests on Cisco Webex     Login Issue
# 31                       Overview and Troubleshooting  Software Issue
# 32            User Cannot Login to iLearn (SSO Error)     Login Issue
# 33  Unable to connect through remote desktop conne...  Software Issue
# 34  Outlook Preventing email forwarding on MAC dev...  Software Issue
# 35                Secure Printing to Kyocera Printers   Printer Issue
# 36          Outlook - Program only opens in safe mode  Software Issue
# 37  SharePoint Online - User is prompted to login ...     Login Issue
# 38  Adding the charges to the ambulatory summary page  Software Issue
# 39  Chrome - Can't open, asking for administrator ...     Login Issue
# 40           Calendars Not Syncing on iPhone and iPad  Software Issue
# 41  iPhone or iPad - kids powerchart Aria EEG iPho...  Hardware Issue
# 42  How to Set Internet Explorer as the Default Br...  Software Issue
# 43  Outlook Web App - How to set up Out of office ...  Software Issue
# 44                         Access to CAFE application     Login Issue
# 45  Encounter Search box is blank; can't search fo...    Search Issue
# 46                The printing preview is not showing   Printer Issue
# 47                      Monitor and Mouse not working  Hardware Issue
# 48  PeopleSoft - Error, "Only one primary email ad...     Login Issue
# 49      Employee Barcodes not scanning on the machine  Hardware Issue
#
#                                                 lower  \
# 0   unable to print from scheduler. no printers ap...
# 1             mouse is not showing in the device list
# 2             reset star password allscripts mckesson
# 3                how to filter medications and orders
# 4                            web browser installation
# 5       how to create a new powernote from an old one
# 6                   the paper is stuck in the printer
# 7                         client is already logged in
# 8   resetting bridge medical (blood transfusion) p...
# 9                                        login issues
# 10                      find archived irm code pagers
# 11                        printer not showing in list
# 12                        how to find the or schedule
# 13  failed network connectivity error message:  rp...
# 14          how to submit a technology review request
# 15  one or more employees are not showing up on ma...
# 16                                      user security
# 17                    how to get an anesthesia record
# 18                          the remote is not working
# 19           e-prescribe dispense units not available
# 20                        how to reset citrix profile
# 21           how to find my application on the server
# 22                                     password reset
# 23  powernote error: error in the text filter: ill...
# 24                         windows activation pop out
# 25                how to change clairvia web password
# 26  can't log in to ocie. forgot password or accou...
# 27                         application not opening up
# 28   cisco security appliance wired connection issues
# 29  how to enable a computer that is not connectin...
# 30                     access requests on cisco webex
# 31                       overview and troubleshooting
# 32            user cannot login to ilearn (sso error)
# 33  unable to connect through remote desktop conne...
# 34  outlook preventing email forwarding on mac dev...
# 35                secure printing to kyocera printers
# 36          outlook - program only opens in safe mode
# 37  sharepoint online - user is prompted to login ...
# 38  adding the charges to the ambulatory summary page
# 39  chrome - can't open, asking for administrator ...
# 40           calendars not syncing on iphone and ipad
# 41  iphone or ipad - kids powerchart aria eeg ipho...
# 42  how to set internet explorer as the default br...
# 43  outlook web app - how to set up out of office ...
# 44                         access to cafe application
# 45  encounter search box is blank; can't search fo...
# 46                the printing preview is not showing
# 47                      monitor and mouse not working
# 48  peoplesoft - error, "only one primary email ad...
# 49      employee barcodes not scanning on the machine
#
#                                             tokenized  \
# 0   [unable, to, print, from, scheduler, ., no, pr...
# 1    [mouse, is, not, showing, in, the, device, list]
# 2       [reset, star, password, allscripts, mckesson]
# 3         [how, to, filter, medications, and, orders]
# 4                        [web, browser, installation]
# 5   [how, to, create, a, new, powernote, from, an,...
# 6           [the, paper, is, stuck, in, the, printer]
# 7                   [client, is, already, logged, in]
# 8   [resetting, bridge, medical, (, blood, transfu...
# 9                                     [login, issues]
# 10                [find, archived, irm, code, pagers]
# 11                  [printer, not, showing, in, list]
# 12                 [how, to, find, the, or, schedule]
# 13  [failed, network, connectivity, error, message...
# 14  [how, to, submit, a, technology, review, request]
# 15  [one, or, more, employees, are, not, showing, ...
# 16                                   [user, security]
# 17             [how, to, get, an, anesthesia, record]
# 18                    [the, remote, is, not, working]
# 19     [e-prescribe, dispense, units, not, available]
# 20                  [how, to, reset, citrix, profile]
# 21  [how, to, find, my, application, on, the, server]
# 22                                  [password, reset]
# 23  [powernote, error, :, error, in, the, text, fi...
# 24                    [windows, activation, pop, out]
# 25         [how, to, change, clairvia, web, password]
# 26  [ca, n't, log, in, to, ocie, ., forgot, passwo...
# 27                    [application, not, opening, up]
# 28  [cisco, security, appliance, wired, connection...
# 29  [how, to, enable, a, computer, that, is, not, ...
# 30               [access, requests, on, cisco, webex]
# 31                   [overview, and, troubleshooting]
# 32  [user, can, not, login, to, ilearn, (, sso, er...
# 33  [unable, to, connect, through, remote, desktop...
# 34  [outlook, preventing, email, forwarding, on, m...
# 35          [secure, printing, to, kyocera, printers]
# 36  [outlook, -, program, only, opens, in, safe, m...
# 37  [sharepoint, online, -, user, is, prompted, to...
# 38  [adding, the, charges, to, the, ambulatory, su...
# 39  [chrome, -, ca, n't, open, ,, asking, for, adm...
# 40   [calendars, not, syncing, on, iphone, and, ipad]
# 41  [iphone, or, ipad, -, kids, powerchart, aria, ...
# 42  [how, to, set, internet, explorer, as, the, de...
# 43  [outlook, web, app, -, how, to, set, up, out, ...
# 44                    [access, to, cafe, application]
# 45  [encounter, search, box, is, blank, ;, ca, n't...
# 46         [the, printing, preview, is, not, showing]
# 47                [monitor, and, mouse, not, working]
# 48  [peoplesoft, -, error, ,, ``, only, one, prima...
# 49  [employee, barcodes, not, scanning, on, the, m...
#
#                                              selected  \
# 0   [unable, print, scheduler, printers, appear, f...
# 1                      [mouse, showing, device, list]
# 2       [reset, star, password, allscripts, mckesson]
# 3                       [filter, medications, orders]
# 4                        [web, browser, installation]
# 5                  [create, new, powernote, old, one]
# 6                             [paper, stuck, printer]
# 7                           [client, already, logged]
# 8   [resetting, bridge, medical, blood, transfusio...
# 9                                     [login, issues]
# 10                [find, archived, irm, code, pagers]
# 11                           [printer, showing, list]
# 12                                   [find, schedule]
# 13  [failed, network, connectivity, error, message...
# 14              [submit, technology, review, request]
# 15  [one, employees, showing, manager, 's, team, v...
# 16                                   [user, security]
# 17                          [get, anesthesia, record]
# 18                                  [remote, working]
# 19          [e-prescribe, dispense, units, available]
# 20                           [reset, citrix, profile]
# 21                        [find, application, server]
# 22                                  [password, reset]
# 23  [powernote, error, error, text, filter, illega...
# 24                         [windows, activation, pop]
# 25                  [change, clairvia, web, password]
# 26  [ca, n't, log, ocie, forgot, password, account...
# 27                             [application, opening]
# 28  [cisco, security, appliance, wired, connection...
# 29  [enable, computer, connecting, chla, staff, wifi]
# 30                   [access, requests, cisco, webex]
# 31                        [overview, troubleshooting]
# 32                  [user, login, ilearn, sso, error]
# 33     [unable, connect, remote, desktop, connection]
# 34  [outlook, preventing, email, forwarding, mac, ...
# 35              [secure, printing, kyocera, printers]
# 36              [outlook, program, opens, safe, mode]
# 37  [sharepoint, online, user, prompted, login, sh...
# 38       [adding, charges, ambulatory, summary, page]
# 39  [chrome, ca, n't, open, asking, administrator,...
# 40                 [calendars, syncing, iphone, ipad]
# 41  [iphone, ipad, kids, powerchart, aria, eeg, ip...
# 42        [set, internet, explorer, default, browser]
# 43  [outlook, web, app, set, office, assistant, we...
# 44                        [access, cafe, application]
# 45  [encounter, search, box, blank, ca, n't, searc...
# 46                       [printing, preview, showing]
# 47                          [monitor, mouse, working]
# 48  [peoplesoft, error, ``, one, primary, email, a...
# 49            [employee, barcodes, scanning, machine]
#
#                                            lemmatized  \
# 0   [unable, print, scheduler, printer, appear, fa...
# 1                      [mouse, showing, device, list]
# 2       [reset, star, password, allscripts, mckesson]
# 3                         [filter, medication, order]
# 4                        [web, browser, installation]
# 5                  [create, new, powernote, old, one]
# 6                             [paper, stuck, printer]
# 7                           [client, already, logged]
# 8   [resetting, bridge, medical, blood, transfusio...
# 9                                      [login, issue]
# 10                 [find, archived, irm, code, pager]
# 11                           [printer, showing, list]
# 12                                   [find, schedule]
# 13  [failed, network, connectivity, error, message...
# 14              [submit, technology, review, request]
# 15  [one, employee, showing, manager, 's, team, view]
# 16                                   [user, security]
# 17                          [get, anesthesia, record]
# 18                                  [remote, working]
# 19           [e-prescribe, dispense, unit, available]
# 20                           [reset, citrix, profile]
# 21                        [find, application, server]
# 22                                  [password, reset]
# 23  [powernote, error, error, text, filter, illega...
# 24                          [window, activation, pop]
# 25                  [change, clairvia, web, password]
# 26  [ca, n't, log, ocie, forgot, password, account...
# 27                             [application, opening]
# 28  [cisco, security, appliance, wired, connection...
# 29  [enable, computer, connecting, chla, staff, wifi]
# 30                    [access, request, cisco, webex]
# 31                        [overview, troubleshooting]
# 32                  [user, login, ilearn, sso, error]
# 33     [unable, connect, remote, desktop, connection]
# 34  [outlook, preventing, email, forwarding, mac, ...
# 35               [secure, printing, kyocera, printer]
# 36               [outlook, program, open, safe, mode]
# 37  [sharepoint, online, user, prompted, login, sh...
# 38        [adding, charge, ambulatory, summary, page]
# 39  [chrome, ca, n't, open, asking, administrator,...
# 40                  [calendar, syncing, iphone, ipad]
# 41  [iphone, ipad, kid, powerchart, aria, eeg, iph...
# 42        [set, internet, explorer, default, browser]
# 43  [outlook, web, app, set, office, assistant, we...
# 44                        [access, cafe, application]
# 45  [encounter, search, box, blank, ca, n't, searc...
# 46                       [printing, preview, showing]
# 47                          [monitor, mouse, working]
# 48  [peoplesoft, error, ``, one, primary, email, a...
# 49            [employee, barcodes, scanning, machine]
#
#                                            normalized
# 0      unable print scheduler printer appear favorite
# 1                           mouse showing device list
# 2             reset star password allscripts mckesson
# 3                             filter medication order
# 4                            web browser installation
# 5                        create new powernote old one
# 6                                 paper stuck printer
# 7                               client already logged
# 8   resetting bridge medical blood transfusion pas...
# 9                                         login issue
# 10                       find archived irm code pager
# 11                               printer showing list
# 12                                      find schedule
# 13  failed network connectivity error message rpc ...
# 14                   submit technology review request
# 15          one employee showing manager 's team view
# 16                                      user security
# 17                              get anesthesia record
# 18                                     remote working
# 19                e-prescribe dispense unit available
# 20                               reset citrix profile
# 21                            find application server
# 22                                     password reset
# 23    powernote error error text filter illegal token
# 24                              window activation pop
# 25                       change clairvia web password
# 26     ca n't log ocie forgot password account locked
# 27                                application opening
# 28    cisco security appliance wired connection issue
# 29         enable computer connecting chla staff wifi
# 30                         access request cisco webex
# 31                           overview troubleshooting
# 32                        user login ilearn sso error
# 33           unable connect remote desktop connection
# 34     outlook preventing email forwarding mac device
# 35                    secure printing kyocera printer
# 36                     outlook program open safe mode
# 37  sharepoint online user prompted login sharepoi...
# 38              adding charge ambulatory summary page
# 39   chrome ca n't open asking administrator password
# 40                       calendar syncing iphone ipad
# 41  iphone ipad kid powerchart aria eeg iphone 6 plus
# 42              set internet explorer default browser
# 43       outlook web app set office assistant webmail
# 44                            access cafe application
# 45  encounter search box blank ca n't search patie...
# 46                           printing preview showing
# 47                              monitor mouse working
# 48  peoplesoft error `` one primary email address ...
# 49                 employee barcodes scanning machine

# %%
# #train_test_split

# from sklearn.model_selection import train_test_split

# train_data, test_data = train_test_split(data, test_size = 0.15, random_state = 5)

# %%
train_data = data

# %%
#tf_tokenize

from tensorflow.keras.preprocessing.text import Tokenizer

max_num_words = 10000

tokenizer = Tokenizer(num_words = max_num_words)
tokenizer.fit_on_texts(train_data.normalized)

word_index = tokenizer.word_index

tokenized_train = tokenizer.texts_to_sequences(train_data.normalized)
# tokenized_test = tokenizer.texts_to_sequences(test_data.normalized)

# %%
len(word_index)
# Out:
# 173

# %%
#max_len_of_sentences

maxLen = 0
for t in tokenized_train:
    if len(t) > maxLen:
        maxLen = len(t)

maxLen
# Out:
# 12

# %%
#padding

from tensorflow.keras.preprocessing.sequence import pad_sequences

train_padded = pad_sequences(tokenized_train, maxlen = maxLen, padding = "post")
# test_padded = pad_sequences(tokenized_test, maxlen = maxLen, padding = "post")

# %%
print(train_padded.shape)
# Out:
# (50, 12)

# %%
#one_hot_encoded_x

def transform_x(data, tokenizer):
    output_shape = [data.shape[0],
                  data.shape[1],
                  tokenizer.word_index.keys().__len__()]
    results = np.zeros(output_shape)
    
    for i in range(data.shape[0]):
        for ii in range(data.shape[1]):
            results[i, ii, data[i,ii]-1]= 1
    return results

xtr_transformed = transform_x(train_padded, tokenizer)
# xts_transformed = transform_x(test_padded, tokenizer)

# %%
xtr_transformed.shape
# Out:
# (50, 12, 173)

# %%
#one_hot_encoded_y

from sklearn.preprocessing import OneHotEncoder as OHE

y_encoder = OHE().fit(np.array(train_data.intent).reshape(-1,1))

ytr_encoded = y_encoder.transform(np.array(train_data.intent).reshape(-1,1)).toarray()
# yts_encoded = y_encoder.transform(np.array(test_data.intent).reshape(-1,1)).toarray()

# %%
ytr_encoded.shape
# Out:
# (50, 5)

# %%
embeddings_index={}
with open('glove.6B.100d.txt', encoding='utf8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# %%
all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
num_words = min(max_num_words, len(word_index))+1
embedding_dim=len(embeddings_index['the'])
embedding_matrix = np.random.normal(emb_mean, emb_std, (num_words, embedding_dim))
for word, i in word_index.items():
    if i >= max_num_words:
        break
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3309: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if await self.run_code(code, result, async_=asy):

# %%
# #CNN

# import tensorflow as tf
# from tensorflow.keras.layers import Input, Embedding, Dense, Flatten, Dropout
# from tensorflow.keras.models import Model, Sequential
# from tensorflow.keras.layers import Conv1D, MaxPooling1D

# embedding_layer = Embedding(num_words, embedding_matrix.shape[1], input_length=train_padded.shape[1], trainable=True)

# sequence_input = Input(shape=(train_padded.shape[1],), dtype='int32')
# embedded_sequences = embedding_layer(sequence_input)
# x = Conv1D(64, 3, activation='relu')(embedded_sequences)
# x = Conv1D(64, 3, activation='relu')(x)
# x = MaxPooling1D(2)(x)
# x = Flatten()(x)
# x = Dense(100, activation='relu')(x)
# preds = Dense(ytr_encoded.shape[1], activation='softmax')(x)
# model = Model(sequence_input, preds)

# model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
# #Regular LSTM

# from tensorflow.keras.layers import Input, Embedding, LSTM, Dense
# from tensorflow.keras.models import Sequential

# model = Sequential()

# model.add(Embedding(num_words, embedding_matrix.shape[1], input_length=train_padded.shape[1],
#           trainable=False, weights=[embedding_matrix]))

# model.add(LSTM(256, return_sequences=True))
# model.add(LSTM(128, return_sequences=False))
# model.add(Dense(256, activation = "relu"))
# model.add(Dense(128, activation = "relu"))
# model.add(Dense(ytr_encoded.shape[1], activation = "softmax"))

# model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
# #Bidirectional LSTM

# import tensorflow as tf
# from tensorflow.python.keras.models import Sequential
# from keras.layers import Dense, Input, Dropout, LSTM, Activation, Bidirectional, Embedding

# model = Sequential()

# model.add(Embedding(num_words, embedding_matrix.shape[1], input_length=train_padded.shape[1],
#           trainable=False, weights=[embedding_matrix]))

# model.add(Bidirectional(LSTM(256, return_sequences=True)))
# model.add(LSTM(128, return_sequences=False))
# model.add(Dense(256, activation = "relu"))
# model.add(Dense(128, activation = "relu"))
# model.add(Dense(ytr_encoded.shape[1], activation = "softmax"))


# model.compile(loss='categorical_crossentropy', optimizer='Nadam', metrics=['accuracy'])

# %%
# #Bidirectional LSTM with Regularization

# import tensorflow as tf
# from tensorflow.python.keras.models import Sequential
# from keras.layers import Dense, Input, Dropout, LSTM, Activation, Bidirectional, Embedding

# model = Sequential()

# model.add(Embedding(num_words, embedding_matrix.shape[1], input_length=train_padded.shape[1], 
#           trainable=False, weights=[embedding_matrix]))
    
# model.add(Bidirectional(LSTM(256, return_sequences=True)))
# model.add(LSTM(128, return_sequences=False))
# model.add(Dense(256, activation = "relu", kernel_regularizer ='l1'))
# model.add(Dense(128, activation = "relu", kernel_regularizer ='l1'))
# model.add(Dense(ytr_encoded.shape[1], activation = "softmax"))


# model.compile(loss="categorical_crossentropy", optimizer="Nadam", metrics=["accuracy"])

# %%
# #Bidirectional LSTM with Regularization and Dropout

# import tensorflow as tf
# from tensorflow.python.keras.models import Sequential
# from keras.layers import Dense, Input, Dropout, LSTM, Activation, Bidirectional, Embedding

# model = Sequential()

# model.add(Embedding(num_words, embedding_matrix.shape[1], input_length=train_padded.shape[1], 
#                     trainable=False, weights=[embedding_matrix]))
    
# model.add(Bidirectional(LSTM(256, return_sequences=True)))
# model.add(Dropout(0.3))
# model.add(LSTM(128, return_sequences=False))
# model.add(Dense(256, activation = "relu", kernel_regularizer ='l2'))
# model.add(Dense(128, activation = "relu", kernel_regularizer ='l2'))
# model.add(Dropout(0.3))
# model.add(Dense(ytr_encoded.shape[1], activation = "softmax"))


# model.compile(loss="categorical_crossentropy", optimizer="Nadam", metrics=["accuracy"])

# %%
#Bidirectional LSTM and Dropout(with Decaying LR)

import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from keras.layers import Dense, Input, Dropout, LSTM, Activation, Bidirectional, Embedding

model = Sequential()

model.add(Embedding(num_words, embedding_matrix.shape[1], input_length=train_padded.shape[1], 
                    trainable=False, weights=[embedding_matrix]))
    
model.add(Bidirectional(LSTM(256, return_sequences=True)))
model.add(Dropout(0.25))
model.add(LSTM(128, return_sequences=False))
model.add(Dense(256, activation = "relu"))
model.add(Dense(128, activation = "relu"))
model.add(Dropout(0.25))
model.add(Dense(ytr_encoded.shape[1], activation = "softmax"))


model.compile(loss="categorical_crossentropy", optimizer="Nadam", metrics=["accuracy"])

# %%
import math
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler

# tensorboard
log_dir = os.path.join('logs', 'custom')
tb_callback = TensorBoard(log_dir=log_dir)

# checkpoint
filepath="models/weights-improvement-{epoch:02d}-{accuracy:.2f}.ckpt"
checkpoint = ModelCheckpoint(filepath, monitor='accuracy', verbose=1,
                             save_weights_only=True, save_best_only=True, mode='max')

# lr_scheduler
def step_decay(epoch):
    initial_lrate = 0.002
    drop = 0.5
    epochs_drop = 4.0
    
    lrate = initial_lrate * math.pow(drop, math.floor((epoch)/epochs_drop))
    print("lr:", lrate)
    
    return lrate
    
#     if lrate >= 0.0000125:
#         return lrate
#     else:
#         return 0.0000125

lrate = LearningRateScheduler(step_decay)

callbacks_list = [lrate, tb_callback]

# %%
import tensorflow as tf

with tf.device('/cpu:0'):
    history = model.fit(train_padded, ytr_encoded, epochs = 40,
          batch_size = 64, shuffle=True, callbacks = callbacks_list)
#with tf.device('/device:GPU:0'):
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer ModuleWrapper has arguments in `__init__` and therefore must override `get_config`.
# Epoch 1/40
# lr: 0.002
# 1/1 [==============================] - 8s 8s/step - loss: 1.6046 - accuracy: 0.2000
# Epoch 2/40
# lr: 0.002
# 1/1 [==============================] - 0s 75ms/step - loss: 1.5481 - accuracy: 0.3200
# Epoch 3/40
# lr: 0.002
# 1/1 [==============================] - 0s 61ms/step - loss: 1.5203 - accuracy: 0.3800
# Epoch 4/40
# lr: 0.002
# 1/1 [==============================] - 0s 70ms/step - loss: 1.5149 - accuracy: 0.3800
# Epoch 5/40
# lr: 0.001
# 1/1 [==============================] - 0s 65ms/step - loss: 1.4062 - accuracy: 0.5000
# Epoch 6/40
# lr: 0.001
# 1/1 [==============================] - 0s 64ms/step - loss: 1.4720 - accuracy: 0.3400
# Epoch 7/40
# lr: 0.001
# 1/1 [==============================] - 0s 64ms/step - loss: 1.6099 - accuracy: 0.3200
# Epoch 8/40
# lr: 0.001
# 1/1 [==============================] - 0s 65ms/step - loss: 1.4177 - accuracy: 0.5000
# Epoch 9/40
# lr: 0.0005
# 1/1 [==============================] - 0s 65ms/step - loss: 1.3064 - accuracy: 0.4200
# Epoch 10/40
# lr: 0.0005
# 1/1 [==============================] - 0s 66ms/step - loss: 1.2005 - accuracy: 0.6000
# Epoch 11/40
# lr: 0.0005
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1055 - accuracy: 0.6600
# Epoch 12/40
# lr: 0.0005
# 1/1 [==============================] - 0s 66ms/step - loss: 1.0108 - accuracy: 0.6600
# Epoch 13/40
# lr: 0.00025
# 1/1 [==============================] - 0s 66ms/step - loss: 0.9442 - accuracy: 0.7600
# Epoch 14/40
# lr: 0.00025
# 1/1 [==============================] - 0s 66ms/step - loss: 0.8788 - accuracy: 0.7800
# Epoch 15/40
# lr: 0.00025
# 1/1 [==============================] - 0s 67ms/step - loss: 0.7973 - accuracy: 0.7800
# Epoch 16/40
# lr: 0.00025
# 1/1 [==============================] - 0s 63ms/step - loss: 0.7330 - accuracy: 0.8600
# Epoch 17/40
# lr: 0.000125
# 1/1 [==============================] - 0s 66ms/step - loss: 0.6793 - accuracy: 0.7800
# Epoch 18/40
# lr: 0.000125
# 1/1 [==============================] - 0s 64ms/step - loss: 0.6657 - accuracy: 0.9200
# Epoch 19/40
# lr: 0.000125
# 1/1 [==============================] - 0s 66ms/step - loss: 0.6446 - accuracy: 0.9000
# Epoch 20/40
# lr: 0.000125
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5752 - accuracy: 0.9200
# Epoch 21/40
# lr: 6.25e-05
# 1/1 [==============================] - 0s 83ms/step - loss: 0.5648 - accuracy: 0.9000
# Epoch 22/40
# lr: 6.25e-05
# 1/1 [==============================] - 0s 66ms/step - loss: 0.5683 - accuracy: 0.8800
# Epoch 23/40
# lr: 6.25e-05
# 1/1 [==============================] - 0s 67ms/step - loss: 0.5023 - accuracy: 0.8800
# Epoch 24/40
# lr: 6.25e-05
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4744 - accuracy: 0.9600
# Epoch 25/40
# lr: 3.125e-05
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4952 - accuracy: 0.9000
# Epoch 26/40
# lr: 3.125e-05
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4703 - accuracy: 0.9200
# Epoch 27/40
# lr: 3.125e-05
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4882 - accuracy: 0.9400
# Epoch 28/40
# lr: 3.125e-05
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4429 - accuracy: 0.9600
# Epoch 29/40
# lr: 1.5625e-05
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4578 - accuracy: 1.0000
# Epoch 30/40
# lr: 1.5625e-05
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4574 - accuracy: 0.9600
# Epoch 31/40
# lr: 1.5625e-05
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4570 - accuracy: 0.9400
# Epoch 32/40
# lr: 1.5625e-05
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4358 - accuracy: 0.9400
# Epoch 33/40
# lr: 7.8125e-06
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4400 - accuracy: 0.9600
# Epoch 34/40
# lr: 7.8125e-06
# 1/1 [==============================] - 0s 80ms/step - loss: 0.4437 - accuracy: 0.9600
# Epoch 35/40
# lr: 7.8125e-06
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4175 - accuracy: 0.9600
# Epoch 36/40
# lr: 7.8125e-06
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4384 - accuracy: 0.9400
# Epoch 37/40
# lr: 3.90625e-06
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4550 - accuracy: 0.9200
# Epoch 38/40
# lr: 3.90625e-06
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4273 - accuracy: 0.9600
# Epoch 39/40
# lr: 3.90625e-06
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4414 - accuracy: 0.9600
# Epoch 40/40
# lr: 3.90625e-06
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4713 - accuracy: 0.9400

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_48 (ModuleWra (None, 12, 100)           17400
# _________________________________________________________________
# module_wrapper_49 (ModuleWra (None, 12, 512)           731136
# _________________________________________________________________
# module_wrapper_50 (ModuleWra (None, 12, 512)           0
# _________________________________________________________________
# module_wrapper_51 (ModuleWra (None, 128)               328192
# _________________________________________________________________
# module_wrapper_52 (ModuleWra (None, 256)               33024
# _________________________________________________________________
# module_wrapper_53 (ModuleWra (None, 128)               32896
# _________________________________________________________________
# module_wrapper_54 (ModuleWra (None, 128)               0
# _________________________________________________________________
# module_wrapper_55 (ModuleWra (None, 5)                 645
# =================================================================
# Total params: 1,143,293
# Trainable params: 1,125,893
# Non-trainable params: 17,400
# _________________________________________________________________

# %%
# import tensorflow as tf

# with tf.device('/cpu:0'):
#     history = model.fit(train_padded, ytr_encoded, epochs = 5,
#           batch_size = 64, shuffle=True,
#           validation_split = 0.15)
# #with tf.device('/device:GPU:0'):

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['accuracy'])
# plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
#performance_evaluation_train

from sklearn.metrics import classification_report

with tf.device('/cpu:0'):
    prediction = y_encoder.inverse_transform(model.predict(train_padded))
print(classification_report(train_data.intent, prediction))
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000019E2BD49670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#                 precision    recall  f1-score   support
#
# Hardware Issue       1.00      0.86      0.92         7
#    Login Issue       1.00      1.00      1.00        15
#  Printer Issue       0.83      1.00      0.91         5
#   Search Issue       1.00      1.00      1.00         9
# Software Issue       1.00      1.00      1.00        14
#
#       accuracy                           0.98        50
#      macro avg       0.97      0.97      0.97        50
#   weighted avg       0.98      0.98      0.98        50

# %%
# #performance_evaluation_test

# from sklearn.metrics import classification_report

# with tf.device('/cpu:0'):
#     prediction_test = y_encoder.inverse_transform(model.predict(test_padded))
# print(classification_report(test_data.intent, prediction_test))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(train_data.intent, prediction)

fig, ax = plt.subplots(figsize=(25,25))
sns.set(font_scale=0.5)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>

# %%
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)

incorr_fraction
# Out:
# array([0.14285714, 0.        , 0.        , 0.        , 0.        ])

# %%
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)

fig, ax = plt.subplots(figsize=(25,25))

plt.bar(np.arange(5), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
# Out:
# Text(0, 0.5, 'Fraction of incorrect predictions')

# %%
import keras
import pickle
import json

from keras.models import save_model

model.save('models/my_model_custom')

with open('utils/classes_custom.pkl','wb') as file:
   pickle.dump(classes,file)

with open('utils/tokenizer_custom.pkl','wb') as file:
   pickle.dump(tokenizer,file)

with open('utils/label_encoder_custom.pkl','wb') as file:
   pickle.dump(y_encoder,file)
# Out:
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_layer_call_fn, dropout_layer_call_and_return_conditional_losses, dense_layer_call_fn while saving (showing 5 of 18). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/my_model_snips\assets
# INFO:tensorflow:Assets written to: models/my_model_snips\assets

# %%
# import keras
# import pickle

# model = keras.models.load_model('models/my_model')

# with open('utils/classes.pkl','rb') as file:
#   classes = pickle.load(file)

# with open('utils/tokenizer.pkl','rb') as file:
#   tokenizer = pickle.load(file)

# with open('utils/label_encoder.pkl','rb') as file:
#   y_encoder = pickle.load(file)
