# %%
import numpy as np
import pandas as pd
import json

# %%
with open('data_full.json') as file:
  data = json.loads(file.read())

# Loading out-of-scope intent data
val_oos = np.array(data['oos_val'])
train_oos = np.array(data['oos_train'])
test_oos = np.array(data['oos_test'])

# Loading other intents data
val_others = np.array(data['val'])
train_others = np.array(data['train'])
test_others = np.array(data['test'])

# Merging out-of-scope and other intent data
val = np.concatenate([val_oos,val_others])
train = np.concatenate([train_oos,train_others])
test = np.concatenate([test_oos,test_others])
data = np.concatenate([train,test,val])
data = data.T

text = data[0]
labels = data[1]

classes = np.unique(labels)

# %%
#convert_to_dataframe

data = pd.DataFrame({'text': text, 'intent': labels})
print(data)
# Out:
#                                                     text         intent
# 0                  how much is an overdraft fee for bank            oos
# 1      why are exponents preformed before multiplicat...            oos
# 2                    what size wipers does this car take            oos
# 3                                  where is the dipstick            oos
# 4                            how much is 1 share of aapl            oos
# ...                                                  ...            ...
# 23695  i was at walmart trying to buy toilet paper an...  card_declined
# 23696       target declined my card and i don't know why  card_declined
# 23697  do you know why my card was declined at target...  card_declined
# 23698  i can't figure out why my card was declined at...  card_declined
# 23699  i was just at target and they declined my card...  card_declined
#
# [23700 rows x 2 columns]

# %%
with pd.option_context('display.max_rows', None):
    print(data.groupby("intent").count())
    
data.groupby("intent").count().shape
# Out:
#                            text
# intent
# accept_reservations         150
# account_blocked             150
# alarm                       150
# application_status          150
# apr                         150
# are_you_a_bot               150
# balance                     150
# bill_balance                150
# bill_due                    150
# book_flight                 150
# book_hotel                  150
# calculator                  150
# calendar                    150
# calendar_update             150
# calories                    150
# cancel                      150
# cancel_reservation          150
# car_rental                  150
# card_declined               150
# carry_on                    150
# change_accent               150
# change_ai_name              150
# change_language             150
# change_speed                150
# change_user_name            150
# change_volume               150
# confirm_reservation         150
# cook_time                   150
# credit_limit                150
# credit_limit_change         150
# credit_score                150
# current_location            150
# damaged_card                150
# date                        150
# definition                  150
# direct_deposit              150
# directions                  150
# distance                    150
# do_you_have_pets            150
# exchange_rate               150
# expiration_date             150
# find_phone                  150
# flight_status               150
# flip_coin                   150
# food_last                   150
# freeze_account              150
# fun_fact                    150
# gas                         150
# gas_type                    150
# goodbye                     150
# greeting                    150
# how_busy                    150
# how_old_are_you             150
# improve_credit_score        150
# income                      150
# ingredient_substitution     150
# ingredients_list            150
# insurance                   150
# insurance_change            150
# interest_rate               150
# international_fees          150
# international_visa          150
# jump_start                  150
# last_maintenance            150
# lost_luggage                150
# make_call                   150
# maybe                       150
# meal_suggestion             150
# meaning_of_life             150
# measurement_conversion      150
# meeting_schedule            150
# min_payment                 150
# mpg                         150
# new_card                    150
# next_holiday                150
# next_song                   150
# no                          150
# nutrition_info              150
# oil_change_how              150
# oil_change_when             150
# oos                        1200
# order                       150
# order_checks                150
# order_status                150
# pay_bill                    150
# payday                      150
# pin_change                  150
# play_music                  150
# plug_type                   150
# pto_balance                 150
# pto_request                 150
# pto_request_status          150
# pto_used                    150
# recipe                      150
# redeem_rewards              150
# reminder                    150
# reminder_update             150
# repeat                      150
# replacement_card_duration   150
# report_fraud                150
# report_lost_card            150
# reset_settings              150
# restaurant_reservation      150
# restaurant_reviews          150
# restaurant_suggestion       150
# rewards_balance             150
# roll_dice                   150
# rollover_401k               150
# routing                     150
# schedule_maintenance        150
# schedule_meeting            150
# share_location              150
# shopping_list               150
# shopping_list_update        150
# smart_home                  150
# spelling                    150
# spending_history            150
# sync_device                 150
# taxes                       150
# tell_joke                   150
# text                        150
# thank_you                   150
# time                        150
# timer                       150
# timezone                    150
# tire_change                 150
# tire_pressure               150
# todo_list                   150
# todo_list_update            150
# traffic                     150
# transactions                150
# transfer                    150
# translate                   150
# travel_alert                150
# travel_notification         150
# travel_suggestion           150
# uber                        150
# update_playlist             150
# user_name                   150
# vaccines                    150
# w2                          150
# weather                     150
# what_are_your_hobbies       150
# what_can_i_ask_you          150
# what_is_your_name           150
# what_song                   150
# where_are_you_from          150
# whisper_mode                150
# who_do_you_work_for         150
# who_made_you                150
# yes                         150
# (151, 1)

# %%
#convert_to_lower_case

data["lower"] = data.text.map(lambda x : x.lower())

# %%
# import nltk
# nltk.download("punkt")
# nltk.download("stopwords")

# %%
#word_tokenize

from nltk import word_tokenize

data["tokenized"] = data.lower.map(word_tokenize)

# %%
#stopwords_remove

from nltk.corpus import stopwords
from string import punctuation

def remove_stop(strings, stop_list):
    classed = [s for s in strings if s not in stop_list]
    return classed

stop = stopwords.words("english")
stop_punc = list(set(punctuation)) + stop

data["selected"] = data.tokenized.map(lambda df: remove_stop(df, stop_punc))

# %%
#normalize

from nltk.stem import PorterStemmer

def normalize(text):
    return " ".join(text)

stemmer= PorterStemmer()

data["stemmed"] = data.selected.map(lambda xs: [stemmer.stem(x) for x in xs])
data["normalized"] = data.stemmed.apply(normalize)

data
# Out:
#                                                     text         intent  \
# 0                  how much is an overdraft fee for bank            oos
# 1      why are exponents preformed before multiplicat...            oos
# 2                    what size wipers does this car take            oos
# 3                                  where is the dipstick            oos
# 4                            how much is 1 share of aapl            oos
# ...                                                  ...            ...
# 23695  i was at walmart trying to buy toilet paper an...  card_declined
# 23696       target declined my card and i don't know why  card_declined
# 23697  do you know why my card was declined at target...  card_declined
# 23698  i can't figure out why my card was declined at...  card_declined
# 23699  i was just at target and they declined my card...  card_declined
#
#                                                    lower  \
# 0                  how much is an overdraft fee for bank
# 1      why are exponents preformed before multiplicat...
# 2                    what size wipers does this car take
# 3                                  where is the dipstick
# 4                            how much is 1 share of aapl
# ...                                                  ...
# 23695  i was at walmart trying to buy toilet paper an...
# 23696       target declined my card and i don't know why
# 23697  do you know why my card was declined at target...
# 23698  i can't figure out why my card was declined at...
# 23699  i was just at target and they declined my card...
#
#                                                tokenized  \
# 0         [how, much, is, an, overdraft, fee, for, bank]
# 1      [why, are, exponents, preformed, before, multi...
# 2            [what, size, wipers, does, this, car, take]
# 3                             [where, is, the, dipstick]
# 4                    [how, much, is, 1, share, of, aapl]
# ...                                                  ...
# 23695  [i, was, at, walmart, trying, to, buy, toilet,...
# 23696  [target, declined, my, card, and, i, do, n't, ...
# 23697  [do, you, know, why, my, card, was, declined, ...
# 23698  [i, ca, n't, figure, out, why, my, card, was, ...
# 23699  [i, was, just, at, target, and, they, declined...
#
#                                                 selected  \
# 0                           [much, overdraft, fee, bank]
# 1      [exponents, preformed, multiplication, order, ...
# 2                              [size, wipers, car, take]
# 3                                             [dipstick]
# 4                                 [much, 1, share, aapl]
# ...                                                  ...
# 23695  [walmart, trying, buy, toilet, paper, card, go...
# 23696                [target, declined, card, n't, know]
# 23697    [know, card, declined, target, ca, n't, figure]
# 23698          [ca, n't, figure, card, declined, target]
# 23699      [target, declined, card, ca, n't, understand]
#
#                                                  stemmed  \
# 0                           [much, overdraft, fee, bank]
# 1                 [expon, preform, multipl, order, oper]
# 2                               [size, wiper, car, take]
# 3                                             [dipstick]
# 4                                 [much, 1, share, aapl]
# ...                                                  ...
# 23695  [walmart, tri, buy, toilet, paper, card, got, ...
# 23696                  [target, declin, card, n't, know]
# 23697       [know, card, declin, target, ca, n't, figur]
# 23698             [ca, n't, figur, card, declin, target]
# 23699        [target, declin, card, ca, n't, understand]
#
#                                          normalized
# 0                           much overdraft fee bank
# 1                  expon preform multipl order oper
# 2                               size wiper car take
# 3                                          dipstick
# 4                                 much 1 share aapl
# ...                                             ...
# 23695  walmart tri buy toilet paper card got declin
# 23696                   target declin card n't know
# 23697          know card declin target ca n't figur
# 23698               ca n't figur card declin target
# 23699          target declin card ca n't understand
#
# [23700 rows x 7 columns]

# %%
#train_test_split

from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(data, test_size = 0.15, random_state = 5)

# %%
#tf_tokenize

from tensorflow.keras.preprocessing.text import Tokenizer

max_num_words = 10000

tokenizer = Tokenizer(num_words = max_num_words)
tokenizer.fit_on_texts(train_data.normalized)

word_index = tokenizer.word_index

tokenized_train = tokenizer.texts_to_sequences(train_data.normalized)
tokenized_test = tokenizer.texts_to_sequences(test_data.normalized)

# %%
len(word_index)
# Out:
# 5299

# %%
#max_len_of_sentences

maxLen = 0
for t in tokenized_train+tokenized_test:
    if len(t) > maxLen:
        maxLen = len(t)

maxLen
# Out:
# 17

# %%
#padding

from tensorflow.keras.preprocessing.sequence import pad_sequences

train_padded = pad_sequences(tokenized_train, maxlen = maxLen, padding = "post")
test_padded = pad_sequences(tokenized_test, maxlen = maxLen, padding = "post")

# %%
print(train_padded.shape, test_padded.shape)
# Out:
# (20145, 17) (3555, 17)

# %%
#one_hot_encoded_x

def transform_x(data, tokenizer):
    output_shape = [data.shape[0],
                  data.shape[1],
                  tokenizer.word_index.keys().__len__()]
    results = np.zeros(output_shape)
    
    for i in range(data.shape[0]):
        for ii in range(data.shape[1]):
            results[i, ii, data[i,ii]-1]= 1
    return results

xtr_transformed = transform_x(train_padded, tokenizer)
xts_transformed = transform_x(test_padded, tokenizer)

# %%
xtr_transformed.shape
# Out:
# (20145, 17, 5299)

# %%
#one_hot_encoded_y

from sklearn.preprocessing import OneHotEncoder as OHE

y_encoder = OHE().fit(np.array(train_data.intent).reshape(-1,1))

ytr_encoded = y_encoder.transform(np.array(train_data.intent).reshape(-1,1)).toarray()
yts_encoded = y_encoder.transform(np.array(test_data.intent).reshape(-1,1)).toarray()

# %%
ytr_encoded.shape
# Out:
# (20145, 151)

# %%
embeddings_index={}
with open('glove.6B.100d.txt', encoding='utf8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# %%
all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
num_words = min(max_num_words, len(word_index))+1
embedding_dim=len(embeddings_index['the'])
embedding_matrix = np.random.normal(emb_mean, emb_std, (num_words, embedding_dim))
for word, i in word_index.items():
    if i >= max_num_words:
        break
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3309: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if await self.run_code(code, result, async_=asy):

# %%
from tensorflow.python.keras.models import Sequential
from keras.layers import Dense, Input, Dropout, LSTM, Activation, Bidirectional, Embedding
model = Sequential()

model.add(Embedding(num_words, 100, trainable=False, input_length=train_padded.shape[1], weights=[embedding_matrix]))

model.add(Bidirectional(LSTM(256, return_sequences=True, recurrent_dropout=0.1, dropout=0.1), 'concat'))
model.add(Dropout(0.3))
model.add(LSTM(256, return_sequences=False, recurrent_dropout=0.1, dropout=0.1))
model.add(Dropout(0.3))
model.add(Dense(50, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(ytr_encoded.shape[1], activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer='Nadam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
import tensorflow as tf

with tf.device('/cpu:0'):
    history = model.fit(train_padded, ytr_encoded, epochs = 30,
          batch_size = 64, shuffle=True,
          validation_split = 0.15)
#with tf.device('/device:GPU:0'):
# Out:
# Epoch 1/30
# 268/268 [==============================] - 71s 230ms/step - loss: 4.7740 - accuracy: 0.0493 - val_loss: 4.1613 - val_accuracy: 0.0655
# Epoch 2/30
# 268/268 [==============================] - 60s 223ms/step - loss: 3.7639 - accuracy: 0.1068 - val_loss: 2.8708 - val_accuracy: 0.2525
# Epoch 3/30
# 268/268 [==============================] - 59s 221ms/step - loss: 2.6907 - accuracy: 0.2691 - val_loss: 1.9519 - val_accuracy: 0.4540
# Epoch 4/30
# 268/268 [==============================] - 62s 232ms/step - loss: 2.0333 - accuracy: 0.4211 - val_loss: 1.5044 - val_accuracy: 0.5735
# Epoch 5/30
# 268/268 [==============================] - 60s 224ms/step - loss: 1.6039 - accuracy: 0.5373 - val_loss: 1.1930 - val_accuracy: 0.6598
# Epoch 6/30
# 268/268 [==============================] - 59s 219ms/step - loss: 1.3178 - accuracy: 0.6263 - val_loss: 1.0036 - val_accuracy: 0.7134
# Epoch 7/30
# 268/268 [==============================] - 60s 225ms/step - loss: 1.1337 - accuracy: 0.6804 - val_loss: 0.9008 - val_accuracy: 0.7429
# Epoch 8/30
# 268/268 [==============================] - 59s 221ms/step - loss: 0.9591 - accuracy: 0.7300 - val_loss: 0.8135 - val_accuracy: 0.7790
# Epoch 9/30
# 268/268 [==============================] - 62s 232ms/step - loss: 0.8578 - accuracy: 0.7585 - val_loss: 0.7809 - val_accuracy: 0.7929
# Epoch 10/30
# 268/268 [==============================] - 60s 226ms/step - loss: 0.7480 - accuracy: 0.7877 - val_loss: 0.7783 - val_accuracy: 0.8064
# Epoch 11/30
# 268/268 [==============================] - 63s 235ms/step - loss: 0.6816 - accuracy: 0.8086 - val_loss: 0.7137 - val_accuracy: 0.8111
# Epoch 12/30
# 268/268 [==============================] - 59s 220ms/step - loss: 0.6151 - accuracy: 0.8257 - val_loss: 0.7028 - val_accuracy: 0.8180
# Epoch 13/30
# 268/268 [==============================] - 59s 219ms/step - loss: 0.5658 - accuracy: 0.8427 - val_loss: 0.7062 - val_accuracy: 0.8236
# Epoch 14/30
# 268/268 [==============================] - 60s 223ms/step - loss: 0.5284 - accuracy: 0.8511 - val_loss: 0.7091 - val_accuracy: 0.8326
# Epoch 15/30
# 268/268 [==============================] - 64s 240ms/step - loss: 0.4817 - accuracy: 0.8602 - val_loss: 0.6981 - val_accuracy: 0.8385
# Epoch 16/30
# 268/268 [==============================] - 60s 224ms/step - loss: 0.4626 - accuracy: 0.8678 - val_loss: 0.7121 - val_accuracy: 0.8395
# Epoch 17/30
# 268/268 [==============================] - 60s 222ms/step - loss: 0.4294 - accuracy: 0.8775 - val_loss: 0.7055 - val_accuracy: 0.8478
# Epoch 18/30
# 268/268 [==============================] - 59s 222ms/step - loss: 0.4066 - accuracy: 0.8855 - val_loss: 0.7003 - val_accuracy: 0.8461
# Epoch 19/30
# 268/268 [==============================] - 60s 225ms/step - loss: 0.3793 - accuracy: 0.8913 - val_loss: 0.7151 - val_accuracy: 0.8451
# Epoch 20/30
# 268/268 [==============================] - 59s 220ms/step - loss: 0.3544 - accuracy: 0.8974 - val_loss: 0.7227 - val_accuracy: 0.8504
# Epoch 21/30
# 268/268 [==============================] - 60s 222ms/step - loss: 0.3476 - accuracy: 0.9012 - val_loss: 0.7576 - val_accuracy: 0.8455
# Epoch 22/30
# 268/268 [==============================] - 59s 221ms/step - loss: 0.3511 - accuracy: 0.8997 - val_loss: 0.7547 - val_accuracy: 0.8527
# Epoch 23/30
# 268/268 [==============================] - 61s 226ms/step - loss: 0.3151 - accuracy: 0.9077 - val_loss: 0.7244 - val_accuracy: 0.8577
# Epoch 24/30
# 268/268 [==============================] - 61s 228ms/step - loss: 0.3077 - accuracy: 0.9113 - val_loss: 0.7494 - val_accuracy: 0.8494
# Epoch 25/30
# 268/268 [==============================] - 59s 221ms/step - loss: 0.2857 - accuracy: 0.9183 - val_loss: 0.7567 - val_accuracy: 0.8627
# Epoch 26/30
# 268/268 [==============================] - 60s 223ms/step - loss: 0.2587 - accuracy: 0.9244 - val_loss: 0.6981 - val_accuracy: 0.8663
# Epoch 27/30
# 268/268 [==============================] - 60s 222ms/step - loss: 0.2718 - accuracy: 0.9199 - val_loss: 0.7650 - val_accuracy: 0.8676
# Epoch 28/30
# 268/268 [==============================] - 59s 221ms/step - loss: 0.2636 - accuracy: 0.9197 - val_loss: 0.7498 - val_accuracy: 0.8670
# Epoch 29/30
# 268/268 [==============================] - 60s 222ms/step - loss: 0.2643 - accuracy: 0.9240 - val_loss: 0.7787 - val_accuracy: 0.8534
# Epoch 30/30
# 268/268 [==============================] - 60s 224ms/step - loss: 0.2402 - accuracy: 0.9289 - val_loss: 0.8144 - val_accuracy: 0.8693

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper (ModuleWrappe (None, 17, 100)           530000
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (None, 17, 512)           731136
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (None, 17, 512)           0
# _________________________________________________________________
# module_wrapper_3 (ModuleWrap (None, 256)               787456
# _________________________________________________________________
# module_wrapper_4 (ModuleWrap (None, 256)               0
# _________________________________________________________________
# module_wrapper_5 (ModuleWrap (None, 50)                12850
# _________________________________________________________________
# module_wrapper_6 (ModuleWrap (None, 50)                0
# _________________________________________________________________
# module_wrapper_7 (ModuleWrap (None, 151)               7701
# =================================================================
# Total params: 2,069,143
# Trainable params: 1,539,143
# Non-trainable params: 530,000
# _________________________________________________________________

# %%
# import tensorflow as tf

# with tf.device('/cpu:0'):
#     history = model.fit(train_padded, ytr_encoded, epochs = 5,
#           batch_size = 64, shuffle=True,
#           validation_split = 0.15)
# #with tf.device('/device:GPU:0'):

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
#performance_evaluation_train

from sklearn.metrics import classification_report

with tf.device('/cpu:0'):
    prediction = y_encoder.inverse_transform(model.predict(train_padded))
print(classification_report(train_data.intent, prediction))
# Out:
#                            precision    recall  f1-score   support
#
#       accept_reservations       0.97      0.97      0.97       120
#           account_blocked       0.94      0.89      0.91       126
#                     alarm       0.99      0.98      0.99       129
#        application_status       0.97      0.97      0.97       128
#                       apr       1.00      1.00      1.00       125
#             are_you_a_bot       0.98      0.97      0.97       133
#                   balance       0.98      0.97      0.97       126
#              bill_balance       0.96      0.89      0.93       123
#                  bill_due       0.98      0.83      0.90       130
#               book_flight       1.00      0.99      1.00       122
#                book_hotel       0.99      0.98      0.99       131
#                calculator       0.99      0.98      0.99       133
#                  calendar       0.98      0.95      0.96       130
#           calendar_update       0.95      0.98      0.96       124
#                  calories       0.98      0.98      0.98       130
#                    cancel       0.97      0.92      0.94       132
#        cancel_reservation       0.97      0.98      0.98       130
#                car_rental       0.99      0.99      0.99       139
#             card_declined       0.99      0.96      0.98       129
#                  carry_on       1.00      0.99      1.00       128
#             change_accent       1.00      1.00      1.00       119
#            change_ai_name       0.90      0.61      0.73       122
#           change_language       0.97      0.98      0.97       128
#              change_speed       0.99      0.99      0.99       121
#          change_user_name       0.70      0.85      0.77       122
#             change_volume       0.96      0.96      0.96       128
#       confirm_reservation       0.99      1.00      1.00       132
#                 cook_time       1.00      0.95      0.97       131
#              credit_limit       0.97      0.98      0.98       133
#       credit_limit_change       1.00      0.98      0.99       127
#              credit_score       0.91      0.99      0.95       129
#          current_location       0.98      0.93      0.95       128
#              damaged_card       0.96      0.98      0.97       126
#                      date       0.92      0.97      0.94       123
#                definition       0.98      0.98      0.98       132
#            direct_deposit       0.98      1.00      0.99       126
#                directions       0.95      0.96      0.96       133
#                  distance       0.98      0.98      0.98       130
#          do_you_have_pets       0.98      0.98      0.98       127
#             exchange_rate       0.98      1.00      0.99       131
#           expiration_date       0.98      0.96      0.97       139
#                find_phone       0.97      1.00      0.99       132
#             flight_status       0.98      0.99      0.99       126
#                 flip_coin       1.00      1.00      1.00       124
#                 food_last       0.98      0.98      0.98       128
#            freeze_account       0.92      0.96      0.94       118
#                  fun_fact       1.00      0.99      1.00       131
#                       gas       1.00      0.97      0.98       131
#                  gas_type       0.98      0.99      0.99       127
#                   goodbye       0.98      0.92      0.95       133
#                  greeting       0.64      0.89      0.75       130
#                  how_busy       0.97      0.97      0.97       134
#           how_old_are_you       0.96      0.95      0.95       122
#      improve_credit_score       0.98      0.88      0.93       129
#                    income       0.95      0.92      0.93       134
#   ingredient_substitution       0.98      1.00      0.99       129
#          ingredients_list       1.00      0.93      0.96       131
#                 insurance       0.99      1.00      1.00       135
#          insurance_change       1.00      0.99      1.00       121
#             interest_rate       0.99      0.98      0.99       125
#        international_fees       0.96      1.00      0.98       133
#        international_visa       1.00      0.99      1.00       128
#                jump_start       1.00      1.00      1.00       123
#          last_maintenance       0.99      0.95      0.97       126
#              lost_luggage       0.99      0.98      0.99       123
#                 make_call       0.90      0.90      0.90       126
#                     maybe       0.92      0.86      0.89       127
#           meal_suggestion       0.96      0.98      0.97       132
#           meaning_of_life       0.98      0.98      0.98       129
#    measurement_conversion       1.00      0.99      1.00       126
#          meeting_schedule       0.97      0.96      0.97       120
#               min_payment       0.96      0.99      0.98       127
#                       mpg       0.98      0.98      0.98       126
#                  new_card       0.93      0.96      0.94       121
#              next_holiday       0.96      0.97      0.97       129
#                 next_song       0.96      0.98      0.97       132
#                        no       0.73      0.67      0.70       126
#            nutrition_info       1.00      0.98      0.99       123
#            oil_change_how       0.96      0.89      0.92       123
#           oil_change_when       0.83      0.96      0.89       126
#                       oos       0.94      0.90      0.92      1002
#                     order       0.98      0.94      0.96       129
#              order_checks       0.94      1.00      0.97       130
#              order_status       0.95      0.98      0.96       124
#                  pay_bill       0.89      0.98      0.93       126
#                    payday       0.97      0.98      0.98       128
#                pin_change       0.99      1.00      1.00       122
#                play_music       0.92      0.98      0.95       123
#                 plug_type       1.00      1.00      1.00       127
#               pto_balance       0.96      0.92      0.94       119
#               pto_request       0.98      0.98      0.98       123
#        pto_request_status       0.93      0.98      0.96       130
#                  pto_used       0.93      0.96      0.94       132
#                    recipe       0.95      1.00      0.97       129
#            redeem_rewards       0.90      0.98      0.94       129
#                  reminder       0.99      0.91      0.95       129
#           reminder_update       0.93      0.98      0.96       131
#                    repeat       0.90      0.92      0.91       131
# replacement_card_duration       0.95      0.97      0.96       125
#              report_fraud       0.94      0.99      0.97       127
#          report_lost_card       1.00      0.98      0.99       134
#            reset_settings       1.00      1.00      1.00       127
#    restaurant_reservation       0.98      0.98      0.98       128
#        restaurant_reviews       0.97      1.00      0.98       128
#     restaurant_suggestion       0.91      0.98      0.95       124
#           rewards_balance       1.00      0.91      0.95       127
#                 roll_dice       1.00      1.00      1.00       121
#             rollover_401k       1.00      1.00      1.00       128
#                   routing       1.00      1.00      1.00       130
#      schedule_maintenance       1.00      0.93      0.96       128
#          schedule_meeting       0.98      0.98      0.98       130
#            share_location       0.96      0.97      0.96       132
#             shopping_list       0.93      0.94      0.93       128
#      shopping_list_update       0.95      0.97      0.96       127
#                smart_home       0.96      0.99      0.98       128
#                  spelling       1.00      0.99      1.00       130
#          spending_history       0.97      0.97      0.97       129
#               sync_device       0.99      1.00      1.00       127
#                     taxes       0.98      0.97      0.97       130
#                 tell_joke       0.99      0.99      0.99       132
#                      text       0.99      0.98      0.98       127
#                 thank_you       0.94      0.94      0.94       128
#                      time       0.93      0.97      0.95       131
#                     timer       0.98      1.00      0.99       131
#                  timezone       1.00      0.99      1.00       128
#               tire_change       0.99      0.99      0.99       135
#             tire_pressure       0.98      1.00      0.99       117
#                 todo_list       0.93      0.84      0.88       127
#          todo_list_update       0.94      0.94      0.94       137
#                   traffic       1.00      0.99      1.00       123
#              transactions       0.95      0.95      0.95       129
#                  transfer       0.98      0.99      0.99       123
#                 translate       0.97      0.96      0.96       122
#              travel_alert       1.00      0.98      0.99       123
#       travel_notification       0.98      1.00      0.99       124
#         travel_suggestion       0.97      0.95      0.96       128
#                      uber       1.00      0.98      0.99       122
#           update_playlist       0.99      0.97      0.98       129
#                 user_name       0.56      0.78      0.65       133
#                  vaccines       1.00      1.00      1.00       122
#                        w2       0.98      1.00      0.99       126
#                   weather       0.96      0.98      0.97       131
#     what_are_your_hobbies       0.95      0.98      0.96       130
#        what_can_i_ask_you       0.94      0.87      0.90       126
#         what_is_your_name       0.66      0.35      0.46       130
#                 what_song       0.99      0.95      0.97       133
#        where_are_you_from       0.82      0.85      0.84       126
#              whisper_mode       1.00      0.97      0.98       123
#       who_do_you_work_for       0.89      0.96      0.92       130
#              who_made_you       0.86      0.86      0.86       120
#                       yes       0.76      0.86      0.81       126
#
#                  accuracy                           0.95     20145
#                 macro avg       0.96      0.96      0.95     20145
#              weighted avg       0.96      0.95      0.95     20145

# %%
#performance_evaluation_test

from sklearn.metrics import classification_report

with tf.device('/cpu:0'):
    prediction_test = y_encoder.inverse_transform(model.predict(test_padded))
print(classification_report(test_data.intent, prediction_test))
# Out:
#                            precision    recall  f1-score   support
#
#       accept_reservations       0.96      0.90      0.93        30
#           account_blocked       0.83      0.79      0.81        24
#                     alarm       0.95      1.00      0.98        21
#        application_status       0.95      0.95      0.95        22
#                       apr       0.92      0.96      0.94        25
#             are_you_a_bot       0.88      0.88      0.88        17
#                   balance       0.80      0.83      0.82        24
#              bill_balance       0.77      0.85      0.81        27
#                  bill_due       0.74      0.70      0.72        20
#               book_flight       0.93      0.96      0.95        28
#                book_hotel       0.89      0.89      0.89        19
#                calculator       0.94      0.88      0.91        17
#                  calendar       0.83      0.75      0.79        20
#           calendar_update       0.89      0.96      0.93        26
#                  calories       0.94      0.85      0.89        20
#                    cancel       0.68      0.83      0.75        18
#        cancel_reservation       0.84      0.80      0.82        20
#                car_rental       0.85      1.00      0.92        11
#             card_declined       0.86      0.90      0.88        21
#                  carry_on       1.00      0.86      0.93        22
#             change_accent       0.97      0.94      0.95        31
#            change_ai_name       0.86      0.43      0.57        28
#           change_language       1.00      0.95      0.98        22
#              change_speed       0.97      0.97      0.97        29
#          change_user_name       0.54      0.54      0.54        28
#             change_volume       1.00      0.91      0.95        22
#       confirm_reservation       0.73      0.89      0.80        18
#                 cook_time       0.85      0.89      0.87        19
#              credit_limit       0.93      0.82      0.87        17
#       credit_limit_change       0.91      0.87      0.89        23
#              credit_score       0.87      0.95      0.91        21
#          current_location       0.77      0.77      0.77        22
#              damaged_card       0.88      0.88      0.88        24
#                      date       0.89      0.89      0.89        27
#                definition       0.73      0.61      0.67        18
#            direct_deposit       0.88      0.92      0.90        24
#                directions       0.89      1.00      0.94        17
#                  distance       0.87      0.65      0.74        20
#          do_you_have_pets       0.96      0.96      0.96        23
#             exchange_rate       0.90      1.00      0.95        19
#           expiration_date       0.89      0.73      0.80        11
#                find_phone       0.93      0.78      0.85        18
#             flight_status       1.00      1.00      1.00        24
#                 flip_coin       1.00      0.92      0.96        26
#                 food_last       0.83      0.91      0.87        22
#            freeze_account       0.96      0.75      0.84        32
#                  fun_fact       0.84      0.84      0.84        19
#                       gas       0.76      0.84      0.80        19
#                  gas_type       0.91      0.87      0.89        23
#                   goodbye       0.75      0.88      0.81        17
#                  greeting       0.44      0.80      0.57        20
#                  how_busy       0.79      0.69      0.73        16
#           how_old_are_you       0.96      0.89      0.93        28
#      improve_credit_score       0.95      0.90      0.93        21
#                    income       0.68      0.81      0.74        16
#   ingredient_substitution       0.86      0.86      0.86        21
#          ingredients_list       0.80      0.63      0.71        19
#                 insurance       0.79      1.00      0.88        15
#          insurance_change       1.00      0.90      0.95        29
#             interest_rate       1.00      0.84      0.91        25
#        international_fees       0.89      1.00      0.94        17
#        international_visa       1.00      1.00      1.00        22
#                jump_start       1.00      1.00      1.00        27
#          last_maintenance       1.00      0.83      0.91        24
#              lost_luggage       0.96      0.93      0.94        27
#                 make_call       0.75      0.75      0.75        24
#                     maybe       0.75      0.65      0.70        23
#           meal_suggestion       0.85      0.94      0.89        18
#           meaning_of_life       0.95      0.90      0.93        21
#    measurement_conversion       1.00      0.92      0.96        24
#          meeting_schedule       0.96      0.83      0.89        30
#               min_payment       0.96      0.96      0.96        23
#                       mpg       0.96      0.96      0.96        24
#                  new_card       0.82      0.97      0.89        29
#              next_holiday       0.73      0.90      0.81        21
#                 next_song       0.94      0.94      0.94        18
#                        no       0.60      0.62      0.61        24
#            nutrition_info       0.84      0.96      0.90        27
#            oil_change_how       0.85      0.85      0.85        27
#           oil_change_when       0.71      0.83      0.77        24
#                       oos       0.72      0.63      0.67       198
#                     order       0.85      0.81      0.83        21
#              order_checks       0.68      0.95      0.79        20
#              order_status       0.76      0.85      0.80        26
#                  pay_bill       0.85      0.92      0.88        24
#                    payday       0.94      0.77      0.85        22
#                pin_change       0.96      0.96      0.96        28
#                play_music       0.71      0.89      0.79        27
#                 plug_type       0.91      0.87      0.89        23
#               pto_balance       0.95      0.61      0.75        31
#               pto_request       0.93      0.93      0.93        27
#        pto_request_status       0.75      0.90      0.82        20
#                  pto_used       0.53      0.94      0.68        18
#                    recipe       0.70      0.67      0.68        21
#            redeem_rewards       0.90      0.86      0.88        21
#                  reminder       1.00      0.81      0.89        21
#           reminder_update       1.00      0.84      0.91        19
#                    repeat       0.64      0.74      0.68        19
# replacement_card_duration       0.88      0.84      0.86        25
#              report_fraud       0.84      0.91      0.87        23
#          report_lost_card       0.88      0.94      0.91        16
#            reset_settings       1.00      0.96      0.98        23
#    restaurant_reservation       0.88      0.95      0.91        22
#        restaurant_reviews       0.94      0.73      0.82        22
#     restaurant_suggestion       0.71      0.85      0.77        26
#           rewards_balance       1.00      0.91      0.95        23
#                 roll_dice       1.00      0.97      0.98        29
#             rollover_401k       1.00      0.95      0.98        22
#                   routing       0.95      1.00      0.98        20
#      schedule_maintenance       0.86      0.82      0.84        22
#          schedule_meeting       0.79      0.95      0.86        20
#            share_location       0.77      0.56      0.65        18
#             shopping_list       0.84      0.95      0.89        22
#      shopping_list_update       0.90      0.83      0.86        23
#                smart_home       0.91      0.91      0.91        22
#                  spelling       0.86      0.95      0.90        20
#          spending_history       0.89      0.81      0.85        21
#               sync_device       0.79      0.96      0.86        23
#                     taxes       1.00      1.00      1.00        20
#                 tell_joke       1.00      1.00      1.00        18
#                      text       1.00      0.83      0.90        23
#                 thank_you       0.86      0.86      0.86        22
#                      time       0.95      1.00      0.97        19
#                     timer       0.95      1.00      0.97        19
#                  timezone       1.00      0.95      0.98        22
#               tire_change       1.00      1.00      1.00        15
#             tire_pressure       0.92      1.00      0.96        33
#                 todo_list       0.89      0.74      0.81        23
#          todo_list_update       0.73      0.85      0.79        13
#                   traffic       1.00      0.93      0.96        27
#              transactions       0.76      0.90      0.83        21
#                  transfer       0.89      0.89      0.89        27
#                 translate       0.89      0.89      0.89        28
#              travel_alert       0.96      0.81      0.88        27
#       travel_notification       1.00      1.00      1.00        26
#         travel_suggestion       0.70      0.64      0.67        22
#                      uber       1.00      0.96      0.98        28
#           update_playlist       1.00      0.81      0.89        21
#                 user_name       0.52      0.82      0.64        17
#                  vaccines       0.90      0.96      0.93        28
#                        w2       0.96      0.96      0.96        24
#                   weather       0.82      0.74      0.78        19
#     what_are_your_hobbies       0.95      0.90      0.92        20
#        what_can_i_ask_you       0.83      0.79      0.81        24
#         what_is_your_name       0.55      0.60      0.57        20
#                 what_song       0.94      0.94      0.94        17
#        where_are_you_from       0.52      0.62      0.57        24
#              whisper_mode       0.90      0.96      0.93        27
#       who_do_you_work_for       0.62      0.80      0.70        20
#              who_made_you       0.76      0.73      0.75        30
#                       yes       0.69      0.75      0.72        24
#
#                  accuracy                           0.85      3555
#                 macro avg       0.86      0.86      0.86      3555
#              weighted avg       0.86      0.85      0.85      3555

# %%
import keras
import pickle
import json

from keras.models import save_model

model.save('models/my_model')

with open('utils/classes.pkl','wb') as file:
   pickle.dump(classes,file)

with open('utils/tokenizer.pkl','wb') as file:
   pickle.dump(tokenizer,file)

with open('utils/label_encoder.pkl','wb') as file:
   pickle.dump(y_encoder,file)
# Out:
# WARNING:absl:Found untraced functions such as embedding_layer_call_fn, embedding_layer_call_and_return_conditional_losses, dropout_layer_call_fn, dropout_layer_call_and_return_conditional_losses, dropout_1_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/my_model\assets
# INFO:tensorflow:Assets written to: models/my_model\assets
